# %% [markdown]
# # Rheological data DTS / loss modulus - Preprocessing
#
# **Author:** Lab of Farm Structures
# **Date:** 2026-05

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import math
import re

# %% [markdown]
# ## Import Data

# %%
database = 'Rheological Properties Data Libraries of scl-PHAs'

# %% [markdown]
# ## Create DataFrames for data points and properties

# %%
# Physicochemical properties DataFrame
df_physicochem = pd.read_excel(f'{database}.xlsx', sheet_name='Physchem_properties')

# Complex viscosity properties DataFrame
df_loss = pd.read_excel(f'{database}.xlsx', sheet_name='converted_MPa_Loss_modulus_f2')

# Temperature DataFrame
df_temp = pd.read_excel(f'{database}.xlsx', sheet_name='Temperature')

# Experimental details DataFrame
df_exp = pd.read_excel(f'{database}.xlsx', sheet_name='Rheological_experimental_detail')

# %% [markdown]
# ## Drop duplicates and remove multiple study+instance case (keep first)

# %%
print("Physicochemical Properties, rows before:", df_physicochem.shape[0])
df_physicochem = df_physicochem.drop_duplicates(subset=['Study_id', 'Instance'])
print("Physicochemical Properties, rows after:", df_physicochem.shape[0])
# Out:
# Physicochemical Properties, rows before: 348
# Physicochemical Properties, rows after: 348

# %% [markdown]
# ## Keep DTS data

# %%
exp_dict_dfs = (
    df_exp[df_exp['Test type'] == 'DTS']
    .groupby('Study_id')['Instance']
    .apply(list)
    .to_dict()
)

# %%
# Flatten exp_dict_dfs into a DataFrame of valid (Study_id, Instance) pairs
exp_pairs = [(sid, inst) for sid, instances in exp_dict_dfs.items() for inst in instances]
df_exp_pairs = pd.DataFrame(exp_pairs, columns=['Study_id', 'Instance'])

# Filter df_loss
df_loss_filtered = df_loss.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Filter df_temp
df_temp_filtered = df_temp.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Filter df_exp
df_exp_filtered = df_exp.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# FIlter df_physicochem
df_physic_filtered = df_physicochem.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Check all dfs have the same rows
df_loss_filtered.shape, df_temp_filtered.shape, df_exp_filtered.shape, df_physic_filtered.shape
# Out:
# ((135, 46), (134, 29), (135, 22), (135, 25))

# %% [markdown]
# ## Merge properties

# %%
df_merged_prop = pd.merge(df_physic_filtered, df_exp_filtered,  on=['Study_id', 'Instance'], how='left')
df_merged_prop.tail()
# Out:
#      Study_id Instance Monomer_A Monomer_B  HB_ratio  HV_ratio  Mw_PHBV  \
# 130        60        5       3HB       3HV     100.0       0.0      NaN
# 131        60        6       3HB       3HV     100.0       0.0      NaN
# 132        60        7       3HB       3HV     100.0       0.0      NaN
# 133        60        8       3HB       3HV     100.0       0.0      NaN
# 134        61        1       3HB       3HV     100.0       0.0      NaN
#
#      Mn_PHBV  Density Density_units  ...  Texp Texp_units Viscosity_units  \
# 130      NaN      NaN           NaN  ...   NaN    celsius             NaN
# 131      NaN      NaN           NaN  ...   NaN    celsius             NaN
# 132      NaN      NaN           NaN  ...   NaN    celsius             NaN
# 133      NaN      NaN           NaN  ...   NaN    celsius             NaN
# 134      NaN      NaN           NaN  ...   NaN    celsius             NaN
#
#     Modulus_units  Strain_fixed(%) Frequency_experimental_fixed (Hz)  \
# 130            Pa              NaN                               1.0
# 131            Pa              NaN                               1.0
# 132            Pa              NaN                               1.0
# 133            Pa              NaN                               1.0
# 134           MPa              1.0                               1.0
#
#     Unnamed: 18 Unnamed: 19  Unnamed: 20_y  Row No._y
# 130         NaN         NaN            NaN        344
# 131         NaN         NaN            NaN        345
# 132         NaN         NaN            NaN        346
# 133         NaN         NaN            NaN        347
# 134         NaN         NaN            NaN        348
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Melt temperature values

# %%
id_cols = ["Study_id", "Instance"]

value_cols = [c for c in df_temp_filtered.columns if c not in id_cols]

df_temp_filtered[value_cols] = df_temp_filtered[value_cols].apply(
    pd.to_numeric, errors="coerce"
)
f_long = (
    df_temp_filtered
    .set_index(id_cols)[value_cols]
    .stack()
    .reset_index(name="f_value")
    .dropna(subset=["f_value"])
)
f_long.head()
# Out:
#    Study_id Instance     level_2  f_value
# 0         8        1  Unnamed: 2    -25.0
# 1         8        1  Unnamed: 3    -12.5
# 2         8        1  Unnamed: 4      0.0
# 3         8        1  Unnamed: 5     12.5
# 4         8        1  Unnamed: 6     25.0

# %% [markdown]
# ## Melt loss modulus values

# %%
id_cols = ["Study_id", "Instance"]

value_cols = [c for c in df_loss_filtered.columns if c not in id_cols]

df_loss_filtered[value_cols] = df_loss_filtered[value_cols].apply(
    pd.to_numeric, errors="coerce"
)
v_long = (
    df_loss_filtered
    .set_index(id_cols)[value_cols]
    .stack()
    .reset_index(name="v_value")
    .dropna(subset=["v_value"])
)
v_long.head()
# Out:
#    Study_id Instance     level_2     v_value
# 0         8        1  Unnamed: 3  436.893780
# 1         8        1  Unnamed: 4  406.854191
# 2         8        1  Unnamed: 5  365.762765
# 3         8        1  Unnamed: 6  306.683929
# 4         8        1  Unnamed: 7  217.678942

# %% [markdown]
# ## Merge f and v values

# %%
fv_df = (
    f_long.merge(
        v_long,
        on=["Study_id", "Instance", "level_2"],
        how="inner"
    )
)
fv_df.head()
# Out:
#    Study_id Instance     level_2  f_value     v_value
# 0         8        1  Unnamed: 3    -12.5  436.893780
# 1         8        1  Unnamed: 4      0.0  406.854191
# 2         8        1  Unnamed: 5     12.5  365.762765
# 3         8        1  Unnamed: 6     25.0  306.683929
# 4         8        1  Unnamed: 7     37.5  217.678942

# %%
# check size
f_long.shape, v_long.shape, fv_df.shape
# Out:
# ((1570, 4), (1064, 4), (959, 5))

# %% [markdown]
# ## Merge properties with f,v values

# %%
df_merged_fnl = df_merged_prop.merge(
    fv_df[['Study_id', 'Instance', 'f_value', 'v_value']],
    on=['Study_id', 'Instance'],
    how='left'
)
df_merged_fnl = df_merged_fnl.dropna(subset=['f_value', 'v_value'])
df_merged_fnl.tail()
# Out:
#       Study_id Instance Monomer_A Monomer_B  HB_ratio  HV_ratio  Mw_PHBV  \
# 997         61        1       3HB       3HV     100.0       0.0      NaN
# 998         61        1       3HB       3HV     100.0       0.0      NaN
# 999         61        1       3HB       3HV     100.0       0.0      NaN
# 1000        61        1       3HB       3HV     100.0       0.0      NaN
# 1001        61        1       3HB       3HV     100.0       0.0      NaN
#
#       Mn_PHBV  Density Density_units  ...  Viscosity_units Modulus_units  \
# 997       NaN      NaN           NaN  ...              NaN           MPa
# 998       NaN      NaN           NaN  ...              NaN           MPa
# 999       NaN      NaN           NaN  ...              NaN           MPa
# 1000      NaN      NaN           NaN  ...              NaN           MPa
# 1001      NaN      NaN           NaN  ...              NaN           MPa
#
#      Strain_fixed(%) Frequency_experimental_fixed (Hz)  Unnamed: 18  \
# 997              1.0                               1.0          NaN
# 998              1.0                               1.0          NaN
# 999              1.0                               1.0          NaN
# 1000             1.0                               1.0          NaN
# 1001             1.0                               1.0          NaN
#
#      Unnamed: 19 Unnamed: 20_y Row No._y  f_value  v_value
# 997          NaN           NaN       348    160.0  924.108
# 998          NaN           NaN       348    170.0  278.044
# 999          NaN           NaN       348    180.0   14.536
# 1000         NaN           NaN       348    190.0   11.046
# 1001         NaN           NaN       348    200.0    7.071
#
# [5 rows x 47 columns]

# %%
df_merged_fnl.shape
# Out:
# (959, 47)

# %% [markdown]
# ## Rename columns

# %%
df_merged_fnl = df_merged_fnl.rename(columns={
    'f_value': 'temperature',
    'v_value': 'loss_modulus'
})

df_merged_fnl.columns
# Out:
# Index(['Study_id', 'Instance', 'Monomer_A', 'Monomer_B', 'HB_ratio',
#        'HV_ratio', 'Mw_PHBV', 'Mn_PHBV', 'Density', 'Density_units', 'PDI',
#        'Additive_1', 'Additive1_type', 'Additive1_name',
#        'Additive1_percentage', 'Additive_2', 'Additive2_type',
#        'Additive2_name', 'Additive2_percentage', 'final_PHA_percentage',
#        'Unnamed: 20_x', 'HB_ratio_formulation', 'HV_ratio_formulation',
#        'Unnamed: 23', 'Row No._x', 'Test type', 'constant parameters',
#        'geometry', 'plate diameter', 'gap size', 'morphology', 'diameter',
#        'thickness', 'size units', 'Angular_frequency_units', 'Texp',
#        'Texp_units', 'Viscosity_units', 'Modulus_units', 'Strain_fixed(%)',
#        'Frequency_experimental_fixed (Hz)', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20_y', 'Row No._y', 'temperature', 'loss_modulus'],
#       dtype='object')

# %% [markdown]
# ## Drop duplicates

# %%
df_merged_fnl = df_merged_fnl.drop_duplicates()

# %% [markdown]
# ## Replace N/A values with nan

# %%
df_merged_fnl = df_merged_fnl.replace(
    ["N/A", "n/a", "NA", "na"],
    np.nan
)

# %% [markdown]
# ## Fill in Mw, given PDI = Mw / Mn

# %%
mask_Mw = (
    df_merged_fnl['Mw_PHBV'].isna() &
    df_merged_fnl['Mn_PHBV'].notna() &
    df_merged_fnl['PDI'].notna()
)

df_merged_fnl.loc[mask_Mw, 'Mw_PHBV'] = (
    df_merged_fnl.loc[mask_Mw, 'PDI'] * df_merged_fnl.loc[mask_Mw, 'Mn_PHBV']
)

# %% [markdown]
# ## Fix typos, excl. special characters

# %%
def clean_column_name(col):
    col = col.strip().lower()
    col = re.sub(r'[%()]', '', col)        # remove % ( )
    col = re.sub(r'[\/]', '_', col)        # / → _
    col = re.sub(r'\s+', '_', col)         # spaces → _
    col = re.sub(r'[^a-z0-9_]', '', col)   # remove remaining special chars
    col = re.sub(r'_+', '_', col)           # collapse multiple _
    col = col.strip('_')
    return col

def clean_cell_value(val):
    if isinstance(val, str):
        val = val.strip().lower()
        val = re.sub(r'[%()]', '', val)       # remove % ( )
        val = re.sub(r'[\/]', '_', val)       # / → _
        val = re.sub(r'\s+', '_', val)        # spaces → _
        val = re.sub(r'[^a-z0-9_]', '', val)  # remove remaining special chars
        val = re.sub(r'_+', '_', val)         # collapse multiple _
        val = val.strip('_')
    return val

# %%
df_merged_fnl.columns = [clean_column_name(c) for c in df_merged_fnl.columns]
df_merged_fnl.head()
# Out:
#    study_id instance monomer_a monomer_b  hb_ratio  hv_ratio   mw_phbv  \
# 0         8        1       3HB       3HB     100.0       0.0  490000.0
# 1         8        1       3HB       3HB     100.0       0.0  490000.0
# 2         8        1       3HB       3HB     100.0       0.0  490000.0
# 3         8        1       3HB       3HB     100.0       0.0  490000.0
# 4         8        1       3HB       3HB     100.0       0.0  490000.0
#
#    mn_phbv  density density_units  ...  viscosity_units modulus_units  \
# 0      NaN     1.25         g/cm3  ...             Pa*s           MPa
# 1      NaN     1.25         g/cm3  ...             Pa*s           MPa
# 2      NaN     1.25         g/cm3  ...             Pa*s           MPa
# 3      NaN     1.25         g/cm3  ...             Pa*s           MPa
# 4      NaN     1.25         g/cm3  ...             Pa*s           MPa
#
#   strain_fixed frequency_experimental_fixed_hz  unnamed_18 unnamed_19  \
# 0          NaN                             1.0         NaN        NaN
# 1          NaN                             1.0         NaN        NaN
# 2          NaN                             1.0         NaN        NaN
# 3          NaN                             1.0         NaN        NaN
# 4          NaN                             1.0         NaN        NaN
#
#   unnamed_20_y row_no_y  temperature  loss_modulus
# 0          NaN       29        -12.5    436.893780
# 1          NaN       29          0.0    406.854191
# 2          NaN       29         12.5    365.762765
# 3          NaN       29         25.0    306.683929
# 4          NaN       29         37.5    217.678942
#
# [5 rows x 47 columns]

# %%
df_clean = df_merged_fnl.copy()

# apply only to object (string) columns
obj_cols = df_clean.select_dtypes(include='object').columns

df_clean[obj_cols] = df_clean[obj_cols].apply( lambda col: col.map(clean_cell_value) )

# %%
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio',
#        'hv_ratio', 'mw_phbv', 'mn_phbv', 'density', 'density_units', 'pdi',
#        'additive_1', 'additive1_type', 'additive1_name',
#        'additive1_percentage', 'additive_2', 'additive2_type',
#        'additive2_name', 'additive2_percentage', 'final_pha_percentage',
#        'unnamed_20_x', 'hb_ratio_formulation', 'hv_ratio_formulation',
#        'unnamed_23', 'row_no_x', 'test_type', 'constant_parameters',
#        'geometry', 'plate_diameter', 'gap_size', 'morphology', 'diameter',
#        'thickness', 'size_units', 'angular_frequency_units', 'texp',
#        'texp_units', 'viscosity_units', 'modulus_units', 'strain_fixed',
#        'frequency_experimental_fixed_hz', 'unnamed_18', 'unnamed_19',
#        'unnamed_20_y', 'row_no_y', 'temperature', 'loss_modulus'],
#       dtype='object')

# %%
df_clean.loc[df_clean['additive1_percentage'].isna(), 'additive1_percentage'] = 0
df_clean.loc[df_clean['additive2_percentage'].isna(), 'additive2_percentage'] = 0

df_clean['additive_1'] = df_clean['additive1_percentage'].apply(lambda x: 'yes' if x > 0 else 'no')
df_clean['additive_2'] = df_clean['additive2_percentage'].apply(lambda x: 'yes' if x > 0 else 'no')

df_clean.loc[df_clean['additive_1'] == 'no', 'additive1_type'] = 'not_applicable'
df_clean.loc[df_clean['additive_2'] == 'no', 'additive2_type'] = 'not_applicable'

# %% [markdown]
# ## Drop features with more than 50% missing values

# %%
df_clean = df_clean.loc[:, df_clean.isna().mean() < 0.50]
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio',
#        'hv_ratio', 'mw_phbv', 'additive_1', 'additive1_type', 'additive1_name',
#        'additive1_percentage', 'additive_2', 'additive2_type',
#        'additive2_percentage', 'final_pha_percentage', 'hb_ratio_formulation',
#        'hv_ratio_formulation', 'row_no_x', 'test_type',
#        'angular_frequency_units', 'texp_units', 'modulus_units',
#        'frequency_experimental_fixed_hz', 'row_no_y', 'temperature',
#        'loss_modulus'],
#       dtype='object')

# %% [markdown]
# ## Feature engineering

# %%
df_clean['additive1_type'].value_counts()
# Out:
# additive1_type
# reinforcement         275
# plasticizer           243
# not_applicable        218
# filler                108
# crosslinking_agent     45
# impact_modifier        28
# Name: count, dtype: int64

# %%
additive1_mapping = {
    # already clean
    "plasticizer": "plasticizer_modifier",
    "impact_modifier": "plasticizer_modifier",
    # structural
    "filler": "reinforcement",
    "reinforcement": "reinforcement",
    # chemistry / network
    "crosslinking_agent": "crosslinker_polymer_modifier",
    "blend_polymer": "crosslinker_polymer_modifier",
    # crystallization
    "nucleating_agent": "nucleating_agent",
    # stabilization
    "antioxidant": "stabilizer",
    # none
    "not_applicable": "not_applicable"
}

# %%
df_clean['additive1_type'] = (
    df_clean['additive1_type']
    .map(additive1_mapping)
    .fillna('other')
)

df_clean['additive1_type'].value_counts()
# Out:
# additive1_type
# reinforcement                   383
# plasticizer_modifier            271
# not_applicable                  218
# crosslinker_polymer_modifier     45
# other                            42
# Name: count, dtype: int64

# %%
df_clean['additive2_type'].value_counts()
# Out:
# additive2_type
# not_applicable    780
# plasticizer        94
# reinforcement      71
# compatibilizer     14
# Name: count, dtype: int64

# %% [markdown]
# ## Feature selection

# %%
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio',
#        'hv_ratio', 'mw_phbv', 'additive_1', 'additive1_type', 'additive1_name',
#        'additive1_percentage', 'additive_2', 'additive2_type',
#        'additive2_percentage', 'final_pha_percentage', 'hb_ratio_formulation',
#        'hv_ratio_formulation', 'row_no_x', 'test_type',
#        'angular_frequency_units', 'texp_units', 'modulus_units',
#        'frequency_experimental_fixed_hz', 'row_no_y', 'temperature',
#        'loss_modulus'],
#       dtype='object')

# %%
# Select Features and Target
features = [
            'temperature',
            'study_id',
            'instance',
            'mw_phbv',
            'additive1_type',
            'additive1_percentage',
            'additive2_type',
            'additive2_percentage',
            'hb_ratio_formulation',
            'hv_ratio_formulation'
           ]

target = 'loss_modulus'
measure_unit = 'MPa'

# %%
# Create cleaned DataFrame
df_new = df_clean[features + [target]]

df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 959 entries, 0 to 1001
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   temperature           959 non-null    float64
#  1   study_id              959 non-null    int64
#  2   instance              959 non-null    object
#  3   mw_phbv               509 non-null    float64
#  4   additive1_type        959 non-null    object
#  5   additive1_percentage  959 non-null    float64
#  6   additive2_type        959 non-null    object
#  7   additive2_percentage  959 non-null    float64
#  8   hb_ratio_formulation  884 non-null    float64
#  9   hv_ratio_formulation  884 non-null    float64
#  10  loss_modulus          959 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 89.9+ KB

# %% [markdown]
# ## Drop rows with nan value

# %%
mask = (
    df_new[target].notna() &
    df_new[features].notna().all(axis=1)
)

# Create final dataset
df_final = df_new.loc[mask, features + [target]]
df_final.columns = df_final.columns.str.replace(' ', '_', regex=False)

# Check the DataFrame
df_final.head()
# Out:
#    temperature  study_id instance   mw_phbv        additive1_type  \
# 0        -12.5         8        1  490000.0  plasticizer_modifier
# 1          0.0         8        1  490000.0  plasticizer_modifier
# 2         12.5         8        1  490000.0  plasticizer_modifier
# 3         25.0         8        1  490000.0  plasticizer_modifier
# 4         37.5         8        1  490000.0  plasticizer_modifier
#
#    additive1_percentage  additive2_type  additive2_percentage  \
# 0                  10.0  not_applicable                   0.0
# 1                  10.0  not_applicable                   0.0
# 2                  10.0  not_applicable                   0.0
# 3                  10.0  not_applicable                   0.0
# 4                  10.0  not_applicable                   0.0
#
#    hb_ratio_formulation  hv_ratio_formulation  loss_modulus
# 0                  90.0                   0.0    436.893780
# 1                  90.0                   0.0    406.854191
# 2                  90.0                   0.0    365.762765
# 3                  90.0                   0.0    306.683929
# 4                  90.0                   0.0    217.678942

# %%
df_final['loss_modulus'].describe()
# Out:
# count    5.090000e+02
# mean     1.652144e+06
# std      1.075656e+07
# min      1.714286e+01
# 25%      6.991907e+01
# 50%      1.265949e+02
# 75%      2.322986e+02
# max      1.050050e+08
# Name: loss_modulus, dtype: float64

# %%
df_final['mw_phbv'].describe()
# Out:
# count       509.000000
# mean     368491.695481
# std      174386.532283
# min          98.000000
# 25%      286000.000000
# 50%      350000.000000
# 75%      550000.000000
# max      607000.000000
# Name: mw_phbv, dtype: float64

# %%
df_final = df_final.copy()
df_final['log_loss_modulus'] = np.log10(df_final['loss_modulus'])
df_final['log_mw'] = np.log10(df_final['mw_phbv'])

# %%
df_final.columns
# Out:
# Index(['temperature', 'study_id', 'instance', 'mw_phbv', 'additive1_type',
#        'additive1_percentage', 'additive2_type', 'additive2_percentage',
#        'hb_ratio_formulation', 'hv_ratio_formulation', 'loss_modulus',
#        'log_loss_modulus', 'log_mw'],
#       dtype='object')

# %% [markdown]
# ## Plot feature distribution

# %%
# Numerical columns
numerical_cols_lst = [
    'log_loss_modulus',
    'temperature',
    'log_mw',
    'additive1_percentage',
    'additive2_percentage',
    'hb_ratio_formulation',
    'hv_ratio_formulation'
]
# Categorical columns
categorical_cols_lst = [
    'additive1_type',
    'additive2_type',
]

# %%
def plot_feature_distributions(
    df: pd.DataFrame,
    numerical_cols,
    categorical_cols,
    title_numeric="Model Input Variables and Target Variable (numerical)",
    title_categorical="Model Input Variables (categorical)",
    bins=20,
    max_cols_per_row=4,
    top_k_categories=20,   # cap bars for very high-cardinality cats
):
    # ---------- helper to grid-plot ----------
    def _grid_dims(n, max_cols):
        cols = min(max_cols, max(1, n))
        rows = int(math.ceil(n / cols))
        return rows, cols

    # ---------- NUMERICAL ----------
    if len(numerical_cols) > 0:
        n = len(numerical_cols)
        rows, cols = _grid_dims(n, max_cols_per_row)
        fig, axes = plt.subplots(rows, cols, figsize=(4.0*cols, 3.8*rows))
        axes = np.atleast_2d(axes)
        fig.suptitle(title_numeric, fontsize=14, y=0.98)

        for i, col in enumerate(numerical_cols):
            r, c = divmod(i, cols)
            ax = axes[r, c]
            x = df[col].dropna().values
            ax.hist(x, bins=bins)
            #ax.set_title(str(col), fontsize=10)
            ax.set_ylabel("count of instances")
            ax.set_xlabel(str(col))
            ax.grid(False)

        # hide any empty axes
        for j in range(n, rows*cols):
            r, c = divmod(j, cols)
            axes[r, c].axis("off")

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

    # ---------- CATEGORICAL ----------
    if len(categorical_cols) > 0:
        n = len(categorical_cols)
        rows, cols = _grid_dims(n, max_cols_per_row)
        fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.0*rows))
        axes = np.atleast_2d(axes)
        fig.suptitle(title_categorical, fontsize=14, y=0.98)

        for i, col in enumerate(categorical_cols):
            r, c = divmod(i, cols)
            ax = axes[r, c]
            vc = (df[col].astype(str).replace("nan", np.nan)
                                 .value_counts(dropna=False)
                                 .head(top_k_categories))
            ax.bar(range(len(vc)), vc.values)
            ax.set_xticks(range(len(vc)))
            ax.set_xticklabels(vc.index.astype(str), rotation=30, ha="right", fontsize=9)
            #ax.set_title(str(col), fontsize=10)
            ax.set_ylabel("Count")
            ax.set_xlabel(str(col))
            ax.grid(False)

        # hide any empty axes
        for j in range(n, rows*cols):
            r, c = divmod(j, cols)
            axes[r, c].axis("off")

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

plot_feature_distributions(
    df_final,
    numerical_cols_lst,
    categorical_cols_lst,
    bins=20,
    max_cols_per_row=4,
    top_k_categories=20,
)

# %% [markdown]
# ## Remove features with only one value

# %%
constant_cols = df_final.columns[df_final.nunique(dropna=True) <= 1]
print("Removed columns:", list(constant_cols))
df_final = df_final.drop(columns=constant_cols)
# Out:
# Removed columns: []

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 509 entries, 0 to 923
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   temperature           509 non-null    float64
#  1   study_id              509 non-null    int64
#  2   instance              509 non-null    object
#  3   mw_phbv               509 non-null    float64
#  4   additive1_type        509 non-null    object
#  5   additive1_percentage  509 non-null    float64
#  6   additive2_type        509 non-null    object
#  7   additive2_percentage  509 non-null    float64
#  8   hb_ratio_formulation  509 non-null    float64
#  9   hv_ratio_formulation  509 non-null    float64
#  10  loss_modulus          509 non-null    float64
#  11  log_loss_modulus      509 non-null    float64
#  12  log_mw                509 non-null    float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 55.7+ KB

# %% [markdown]
# ## Save

# %%
df_final.to_csv('rheological_DTS_data_loss_LM.csv', index=False)

# %% [markdown]
# ## Profiling

# %%
import sweetviz as sv

exclude_cols = ['study_id', 'instance']
df_subset = df_final.drop(columns=exclude_cols)

report = sv.analyze(df_subset)
report.show_html("dataset_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report dataset_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
