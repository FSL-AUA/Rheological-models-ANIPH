# %% [markdown]
# # Rheological data DTS / loss modulus - Preprocessing
#
# **Author:** Lab of Farm Structures
# **Date:** 2026-05

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import math
import re

# %% [markdown]
# ## Import Data

# %%
database = 'Rheological Properties Data Libraries of scl-PHAs_V03'

# %% [markdown]
# ## Create DataFrames for data points and properties

# %%
# Physicochemical properties DataFrame
df_physicochem = pd.read_excel(f'{database}.xlsx', sheet_name='Physchem_properties')

# Complex viscosity properties DataFrame
df_loss = pd.read_excel(f'{database}.xlsx', sheet_name='converted_MPa_Loss_modulus_f2')

# Temperature DataFrame
df_temp = pd.read_excel(f'{database}.xlsx', sheet_name='Temperature')

# Experimental details DataFrame
df_exp = pd.read_excel(f'{database}.xlsx', sheet_name='Rheological_experimental_detail')

# %% [markdown]
# ## Drop duplicates and remove multiple study+instance case (keep first)

# %%
print("Physicochemical Properties, rows before:", df_physicochem.shape[0])
df_physicochem = df_physicochem.drop_duplicates(subset=['Study_id', 'Instance'])
print("Physicochemical Properties, rows after:", df_physicochem.shape[0])
# Out:
# Physicochemical Properties, rows before: 336
# Physicochemical Properties, rows after: 336

# %% [markdown]
# ## Keep DTS data

# %%
exp_dict_dfs = (
    df_exp[df_exp['Test type'] == 'DTS']
    .groupby('Study_id')['Instance']
    .apply(list)
    .to_dict()
)

# %%
# Flatten exp_dict_dfs into a DataFrame of valid (Study_id, Instance) pairs
exp_pairs = [(sid, inst) for sid, instances in exp_dict_dfs.items() for inst in instances]
df_exp_pairs = pd.DataFrame(exp_pairs, columns=['Study_id', 'Instance'])

# Filter df_loss
df_loss_filtered = df_loss.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Filter df_temp
df_temp_filtered = df_temp.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Filter df_exp
df_exp_filtered = df_exp.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# FIlter df_physicochem
df_physic_filtered = df_physicochem.merge(df_exp_pairs, on=['Study_id', 'Instance'], how='inner')

# Check all dfs have the same rows
df_loss_filtered.shape, df_temp_filtered.shape, df_exp_filtered.shape, df_physic_filtered.shape
# Out:
# ((127, 46), (126, 29), (127, 22), (127, 22))

# %% [markdown]
# ## Merge properties

# %%
df_merged_prop = pd.merge(df_physic_filtered, df_exp_filtered,  on=['Study_id', 'Instance'], how='left')
df_merged_prop.tail()
# Out:
#      Study_id Instance Monomer_A Monomer_B  HB_ratio (mol%)  HV_ratio (mol%)  \
# 122        60        2       3HB       3HV            100.0              0.0
# 123        60        3       3HB       3HV            100.0              0.0
# 124        60        4       3HB       3HV            100.0              0.0
# 125        60        5       3HB       3HV            100.0              0.0
# 126        61        1       3HB       3HV            100.0              0.0
#
#      Mw_PHBV  Mn_PHBV  Density Density_units  ...  Texp Texp_units  \
# 122      NaN      NaN      NaN           NaN  ...   NaN    celsius
# 123      NaN      NaN      NaN           NaN  ...   NaN    celsius
# 124      NaN      NaN      NaN           NaN  ...   NaN    celsius
# 125      NaN      NaN      NaN           NaN  ...   NaN    celsius
# 126      NaN      NaN      NaN           NaN  ...   NaN    celsius
#
#     Viscosity_units Modulus_units  Strain_fixed(%)  \
# 122             NaN            Pa              NaN
# 123             NaN            Pa              NaN
# 124             NaN            Pa              NaN
# 125             NaN            Pa              NaN
# 126             NaN           MPa              1.0
#
#     Frequency_experimental_fixed (Hz) Unnamed: 18 Unnamed: 19  Unnamed: 20_y  \
# 122                               1.0         NaN         NaN            NaN
# 123                               1.0         NaN         NaN            NaN
# 124                               1.0         NaN         NaN            NaN
# 125                               1.0         NaN         NaN            NaN
# 126                               1.0         NaN         NaN            NaN
#
#      Row No._y
# 122        341
# 123        342
# 124        343
# 125        344
# 126        348
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Melt temperature values

# %%
id_cols = ["Study_id", "Instance"]

value_cols = [c for c in df_temp_filtered.columns if c not in id_cols]

df_temp_filtered[value_cols] = df_temp_filtered[value_cols].apply(
    pd.to_numeric, errors="coerce"
)
f_long = (
    df_temp_filtered
    .set_index(id_cols)[value_cols]
    .stack()
    .reset_index(name="f_value")
    .dropna(subset=["f_value"])
)
f_long.head()
# Out:
#    Study_id Instance     level_2  f_value
# 0         8        1  Unnamed: 2    -25.0
# 1         8        1  Unnamed: 3    -12.5
# 2         8        1  Unnamed: 4      0.0
# 3         8        1  Unnamed: 5     12.5
# 4         8        1  Unnamed: 6     25.0

# %% [markdown]
# ## Melt loss modulus values

# %%
id_cols = ["Study_id", "Instance"]

value_cols = [c for c in df_loss_filtered.columns if c not in id_cols]

df_loss_filtered[value_cols] = df_loss_filtered[value_cols].apply(
    pd.to_numeric, errors="coerce"
)
v_long = (
    df_loss_filtered
    .set_index(id_cols)[value_cols]
    .stack()
    .reset_index(name="v_value")
    .dropna(subset=["v_value"])
)
v_long.head()
# Out:
#    Study_id Instance     level_2     v_value
# 0         8        1  Unnamed: 3  436.893780
# 1         8        1  Unnamed: 4  406.854191
# 2         8        1  Unnamed: 5  365.762765
# 3         8        1  Unnamed: 6  306.683929
# 4         8        1  Unnamed: 7  217.678942

# %% [markdown]
# ## Merge f and v values

# %%
fv_df = (
    f_long.merge(
        v_long,
        on=["Study_id", "Instance", "level_2"],
        how="inner"
    )
)
fv_df.head()
# Out:
#    Study_id Instance     level_2  f_value     v_value
# 0         8        1  Unnamed: 3    -12.5  436.893780
# 1         8        1  Unnamed: 4      0.0  406.854191
# 2         8        1  Unnamed: 5     12.5  365.762765
# 3         8        1  Unnamed: 6     25.0  306.683929
# 4         8        1  Unnamed: 7     37.5  217.678942

# %%
# check size
f_long.shape, v_long.shape, fv_df.shape
# Out:
# ((1511, 4), (1013, 4), (916, 5))

# %% [markdown]
# ## Merge properties with f,v values

# %%
df_merged_fnl = df_merged_prop.merge(
    fv_df[['Study_id', 'Instance', 'f_value', 'v_value']],
    on=['Study_id', 'Instance'],
    how='left'
)
df_merged_fnl = df_merged_fnl.dropna(subset=['f_value', 'v_value'])
df_merged_fnl.tail()
# Out:
#      Study_id Instance Monomer_A Monomer_B  HB_ratio (mol%)  HV_ratio (mol%)  \
# 954        61        1       3HB       3HV            100.0              0.0
# 955        61        1       3HB       3HV            100.0              0.0
# 956        61        1       3HB       3HV            100.0              0.0
# 957        61        1       3HB       3HV            100.0              0.0
# 958        61        1       3HB       3HV            100.0              0.0
#
#      Mw_PHBV  Mn_PHBV  Density Density_units  ...  Viscosity_units  \
# 954      NaN      NaN      NaN           NaN  ...              NaN
# 955      NaN      NaN      NaN           NaN  ...              NaN
# 956      NaN      NaN      NaN           NaN  ...              NaN
# 957      NaN      NaN      NaN           NaN  ...              NaN
# 958      NaN      NaN      NaN           NaN  ...              NaN
#
#     Modulus_units Strain_fixed(%) Frequency_experimental_fixed (Hz)  \
# 954           MPa             1.0                               1.0
# 955           MPa             1.0                               1.0
# 956           MPa             1.0                               1.0
# 957           MPa             1.0                               1.0
# 958           MPa             1.0                               1.0
#
#      Unnamed: 18 Unnamed: 19 Unnamed: 20_y Row No._y  f_value  v_value
# 954          NaN         NaN           NaN       348    160.0  924.108
# 955          NaN         NaN           NaN       348    170.0  278.044
# 956          NaN         NaN           NaN       348    180.0   14.536
# 957          NaN         NaN           NaN       348    190.0   11.046
# 958          NaN         NaN           NaN       348    200.0    7.071
#
# [5 rows x 44 columns]

# %%
df_merged_fnl.shape
# Out:
# (916, 44)

# %% [markdown]
# ## Rename columns

# %%
df_merged_fnl = df_merged_fnl.rename(columns={
    'f_value': 'temperature',
    'v_value': 'loss_modulus'
})

df_merged_fnl.columns
# Out:
# Index(['Study_id', 'Instance', 'Monomer_A', 'Monomer_B', 'HB_ratio (mol%)',
#        'HV_ratio (mol%)', 'Mw_PHBV', 'Mn_PHBV', 'Density', 'Density_units',
#        'PDI', 'Additive_1', 'Additive1_type', 'Additive1_name',
#        'Additive1_percentage (wt%)', 'Additive_2', 'Additive2_type',
#        'Additive2_name', 'Additive2_percentage (wt%)',
#        'final_formulation_PHA_percentage (wt%)', 'Unnamed: 20_x', 'Row No._x',
#        'Test type', 'constant parameters', 'geometry', 'plate diameter',
#        'gap size', 'morphology', 'diameter', 'thickness', 'size units',
#        'Angular_frequency_units', 'Texp', 'Texp_units', 'Viscosity_units',
#        'Modulus_units', 'Strain_fixed(%)', 'Frequency_experimental_fixed (Hz)',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20_y', 'Row No._y',
#        'temperature', 'loss_modulus'],
#       dtype='object')

# %% [markdown]
# ## Drop duplicates

# %%
df_merged_fnl = df_merged_fnl.drop_duplicates()

# %% [markdown]
# ## Replace N/A values with nan

# %%
df_merged_fnl = df_merged_fnl.replace(
    ["N/A", "n/a", "NA", "na"],
    np.nan
)

# %% [markdown]
# ## Fill in Mw, given PDI = Mw / Mn

# %%
mask_Mw = (
    df_merged_fnl['Mw_PHBV'].isna() &
    df_merged_fnl['Mn_PHBV'].notna() &
    df_merged_fnl['PDI'].notna()
)

df_merged_fnl.loc[mask_Mw, 'Mw_PHBV'] = (
    df_merged_fnl.loc[mask_Mw, 'PDI'] * df_merged_fnl.loc[mask_Mw, 'Mn_PHBV']
)

# %% [markdown]
# ## Fix typos, excl. special characters

# %%
def clean_column_name(col):
    col = col.strip().lower()
    col = re.sub(r'[%()]', '', col)        # remove % ( )
    col = re.sub(r'[\/]', '_', col)        # / → _
    col = re.sub(r'\s+', '_', col)         # spaces → _
    col = re.sub(r'[^a-z0-9_]', '', col)   # remove remaining special chars
    col = re.sub(r'_+', '_', col)           # collapse multiple _
    col = col.strip('_')
    return col

def clean_cell_value(val):
    if isinstance(val, str):
        val = val.strip().lower()
        val = re.sub(r'[%()]', '', val)       # remove % ( )
        val = re.sub(r'[\/]', '_', val)       # / → _
        val = re.sub(r'\s+', '_', val)        # spaces → _
        val = re.sub(r'[^a-z0-9_]', '', val)  # remove remaining special chars
        val = re.sub(r'_+', '_', val)         # collapse multiple _
        val = val.strip('_')
    return val

# %%
df_merged_fnl.columns = [clean_column_name(c) for c in df_merged_fnl.columns]
df_merged_fnl.head()
# Out:
#    study_id instance monomer_a monomer_b  hb_ratio_mol  hv_ratio_mol  \
# 0         8        1       3HB       3HB         100.0           0.0
# 1         8        1       3HB       3HB         100.0           0.0
# 2         8        1       3HB       3HB         100.0           0.0
# 3         8        1       3HB       3HB         100.0           0.0
# 4         8        1       3HB       3HB         100.0           0.0
#
#     mw_phbv  mn_phbv  density density_units  ...  viscosity_units  \
# 0  490000.0      NaN     1.25         g/cm3  ...             Pa*s
# 1  490000.0      NaN     1.25         g/cm3  ...             Pa*s
# 2  490000.0      NaN     1.25         g/cm3  ...             Pa*s
# 3  490000.0      NaN     1.25         g/cm3  ...             Pa*s
# 4  490000.0      NaN     1.25         g/cm3  ...             Pa*s
#
#   modulus_units strain_fixed frequency_experimental_fixed_hz  unnamed_18  \
# 0           MPa          NaN                             1.0         NaN
# 1           MPa          NaN                             1.0         NaN
# 2           MPa          NaN                             1.0         NaN
# 3           MPa          NaN                             1.0         NaN
# 4           MPa          NaN                             1.0         NaN
#
#   unnamed_19 unnamed_20_y row_no_y  temperature  loss_modulus
# 0        NaN          NaN       29        -12.5    436.893780
# 1        NaN          NaN       29          0.0    406.854191
# 2        NaN          NaN       29         12.5    365.762765
# 3        NaN          NaN       29         25.0    306.683929
# 4        NaN          NaN       29         37.5    217.678942
#
# [5 rows x 44 columns]

# %%
df_clean = df_merged_fnl.copy()

# apply only to object (string) columns
obj_cols = df_clean.select_dtypes(include='object').columns

df_clean[obj_cols] = df_clean[obj_cols].apply( lambda col: col.map(clean_cell_value) )

# %%
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio_mol',
#        'hv_ratio_mol', 'mw_phbv', 'mn_phbv', 'density', 'density_units', 'pdi',
#        'additive_1', 'additive1_type', 'additive1_name',
#        'additive1_percentage_wt', 'additive_2', 'additive2_type',
#        'additive2_name', 'additive2_percentage_wt',
#        'final_formulation_pha_percentage_wt', 'unnamed_20_x', 'row_no_x',
#        'test_type', 'constant_parameters', 'geometry', 'plate_diameter',
#        'gap_size', 'morphology', 'diameter', 'thickness', 'size_units',
#        'angular_frequency_units', 'texp', 'texp_units', 'viscosity_units',
#        'modulus_units', 'strain_fixed', 'frequency_experimental_fixed_hz',
#        'unnamed_18', 'unnamed_19', 'unnamed_20_y', 'row_no_y', 'temperature',
#        'loss_modulus'],
#       dtype='object')

# %%
df_clean.loc[df_clean['additive1_percentage_wt'].isna(), 'additive1_percentage_wt'] = 0
df_clean.loc[df_clean['additive2_percentage_wt'].isna(), 'additive2_percentage_wt'] = 0

df_clean['additive_1'] = df_clean['additive1_percentage_wt'].apply(lambda x: 'yes' if x > 0 else 'no')
df_clean['additive_2'] = df_clean['additive2_percentage_wt'].apply(lambda x: 'yes' if x > 0 else 'no')

df_clean.loc[df_clean['additive_1'] == 'no', 'additive1_type'] = 'no_additive'
df_clean.loc[df_clean['additive_2'] == 'no', 'additive2_type'] = 'no_additive'

# %% [markdown]
# ## Drop features with more than 50% missing values

# %%
df_clean = df_clean.loc[:, df_clean.isna().mean() < 0.50]
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio_mol',
#        'hv_ratio_mol', 'mw_phbv', 'additive_1', 'additive1_type',
#        'additive1_name', 'additive1_percentage_wt', 'additive_2',
#        'additive2_type', 'additive2_percentage_wt',
#        'final_formulation_pha_percentage_wt', 'row_no_x', 'test_type',
#        'angular_frequency_units', 'texp_units', 'modulus_units',
#        'frequency_experimental_fixed_hz', 'row_no_y', 'temperature',
#        'loss_modulus'],
#       dtype='object')

# %% [markdown]
# ## Feature engineering

# %%
df_clean['additive1_type'].value_counts()
# Out:
# additive1_type
# reinforcment_and_stiffening_modifiers     383
# plasticizers_and_flexibility_enhancers    270
# no_additive                               218
# crosslinking_agent                         45
# Name: count, dtype: int64

# %%
df_clean['additive2_type'].value_counts()
# Out:
# additive2_type
# no_additive                               737
# plasticizers_and_flexibility_enhancers     94
# reinforcment_and_stiffening_modifiers      85
# Name: count, dtype: int64

# %% [markdown]
# ## Feature selection

# %%
df_clean.columns
# Out:
# Index(['study_id', 'instance', 'monomer_a', 'monomer_b', 'hb_ratio_mol',
#        'hv_ratio_mol', 'mw_phbv', 'additive_1', 'additive1_type',
#        'additive1_name', 'additive1_percentage_wt', 'additive_2',
#        'additive2_type', 'additive2_percentage_wt',
#        'final_formulation_pha_percentage_wt', 'row_no_x', 'test_type',
#        'angular_frequency_units', 'texp_units', 'modulus_units',
#        'frequency_experimental_fixed_hz', 'row_no_y', 'temperature',
#        'loss_modulus'],
#       dtype='object')

# %%
# Select Features and Target
features = [
            'temperature',
            'study_id',
            'instance',
            'mw_phbv',
            'additive1_type',
            'additive1_percentage_wt',
            'additive2_type',
            'additive2_percentage_wt',
            'hb_ratio_mol',
            'hv_ratio_mol'
           ]

target = 'loss_modulus'
measure_unit = 'MPa'

# %%
# Create cleaned DataFrame
df_new = df_clean[features + [target]]

df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916 entries, 0 to 958
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   temperature              916 non-null    float64
#  1   study_id                 916 non-null    int64
#  2   instance                 916 non-null    object
#  3   mw_phbv                  465 non-null    float64
#  4   additive1_type           916 non-null    object
#  5   additive1_percentage_wt  916 non-null    float64
#  6   additive2_type           916 non-null    object
#  7   additive2_percentage_wt  916 non-null    float64
#  8   hb_ratio_mol             866 non-null    float64
#  9   hv_ratio_mol             866 non-null    float64
#  10  loss_modulus             916 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 85.9+ KB

# %% [markdown]
# ## Drop rows with nan value

# %%
mask = (
    df_new[target].notna() &
    df_new[features].notna().all(axis=1)
)

# Create final dataset
df_final = df_new.loc[mask, features + [target]]
df_final.columns = df_final.columns.str.replace(' ', '_', regex=False)

# Check the DataFrame
df_final.head()
# Out:
#    temperature  study_id instance   mw_phbv  \
# 0        -12.5         8        1  490000.0
# 1          0.0         8        1  490000.0
# 2         12.5         8        1  490000.0
# 3         25.0         8        1  490000.0
# 4         37.5         8        1  490000.0
#
#                            additive1_type  additive1_percentage_wt  \
# 0  plasticizers_and_flexibility_enhancers                     10.0
# 1  plasticizers_and_flexibility_enhancers                     10.0
# 2  plasticizers_and_flexibility_enhancers                     10.0
# 3  plasticizers_and_flexibility_enhancers                     10.0
# 4  plasticizers_and_flexibility_enhancers                     10.0
#
#   additive2_type  additive2_percentage_wt  hb_ratio_mol  hv_ratio_mol  \
# 0    no_additive                      0.0         100.0           0.0
# 1    no_additive                      0.0         100.0           0.0
# 2    no_additive                      0.0         100.0           0.0
# 3    no_additive                      0.0         100.0           0.0
# 4    no_additive                      0.0         100.0           0.0
#
#    loss_modulus
# 0    436.893780
# 1    406.854191
# 2    365.762765
# 3    306.683929
# 4    217.678942

# %%
df_final['loss_modulus'].describe()
# Out:
# count    4.650000e+02
# mean     1.808467e+06
# std      1.124242e+07
# min      2.001443e+01
# 25%      7.239000e+01
# 50%      1.346856e+02
# 75%      2.714331e+02
# max      1.050050e+08
# Name: loss_modulus, dtype: float64

# %%
df_final['mw_phbv'].describe()
# Out:
# count       465.000000
# mean     403350.406452
# std      138590.388564
# min      150000.000000
# 25%      290000.000000
# 50%      450000.000000
# 75%      550000.000000
# max      607000.000000
# Name: mw_phbv, dtype: float64

# %%
df_final = df_final.copy()
df_final['log_loss_modulus'] = np.log10(df_final['loss_modulus'])
df_final['log_mw'] = np.log10(df_final['mw_phbv'])

# %%
df_final.columns
# Out:
# Index(['temperature', 'study_id', 'instance', 'mw_phbv', 'additive1_type',
#        'additive1_percentage_wt', 'additive2_type', 'additive2_percentage_wt',
#        'hb_ratio_mol', 'hv_ratio_mol', 'loss_modulus', 'log_loss_modulus',
#        'log_mw'],
#       dtype='object')

# %% [markdown]
# ## Plot feature distribution

# %%
# Numerical columns
numerical_cols_lst = [
    'log_loss_modulus',
    'temperature',
    'log_mw',
    'additive1_percentage_wt',
    'additive2_percentage_wt',
    'hb_ratio_mol',
    'hv_ratio_mol'
]
# Categorical columns
categorical_cols_lst = [
    'additive1_type',
    'additive2_type',
]

# %%
def plot_feature_distributions(
    df: pd.DataFrame,
    numerical_cols,
    categorical_cols,
    title_numeric="Model Input Variables and Target Variable (numerical)",
    title_categorical="Model Input Variables (categorical)",
    bins=20,
    max_cols_per_row=4,
    top_k_categories=20,   # cap bars for very high-cardinality cats
):
    # ---------- helper to grid-plot ----------
    def _grid_dims(n, max_cols):
        cols = min(max_cols, max(1, n))
        rows = int(math.ceil(n / cols))
        return rows, cols

    # ---------- NUMERICAL ----------
    if len(numerical_cols) > 0:
        n = len(numerical_cols)
        rows, cols = _grid_dims(n, max_cols_per_row)
        fig, axes = plt.subplots(rows, cols, figsize=(4.0*cols, 3.8*rows))
        axes = np.atleast_2d(axes)
        fig.suptitle(title_numeric, fontsize=14, y=0.98)

        for i, col in enumerate(numerical_cols):
            r, c = divmod(i, cols)
            ax = axes[r, c]
            x = df[col].dropna().values
            ax.hist(x, bins=bins)
            #ax.set_title(str(col), fontsize=10)
            ax.set_ylabel("count of instances")
            ax.set_xlabel(str(col))
            ax.grid(False)

        # hide any empty axes
        for j in range(n, rows*cols):
            r, c = divmod(j, cols)
            axes[r, c].axis("off")

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

    # ---------- CATEGORICAL ----------
    if len(categorical_cols) > 0:
        n = len(categorical_cols)
        rows, cols = _grid_dims(n, max_cols_per_row)
        fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.0*rows))
        axes = np.atleast_2d(axes)
        fig.suptitle(title_categorical, fontsize=14, y=0.98)

        for i, col in enumerate(categorical_cols):
            r, c = divmod(i, cols)
            ax = axes[r, c]
            vc = (df[col].astype(str).replace("nan", np.nan)
                                 .value_counts(dropna=False)
                                 .head(top_k_categories))
            ax.bar(range(len(vc)), vc.values)
            ax.set_xticks(range(len(vc)))
            ax.set_xticklabels(vc.index.astype(str), rotation=30, ha="right", fontsize=9)
            #ax.set_title(str(col), fontsize=10)
            ax.set_ylabel("Count")
            ax.set_xlabel(str(col))
            ax.grid(False)

        # hide any empty axes
        for j in range(n, rows*cols):
            r, c = divmod(j, cols)
            axes[r, c].axis("off")

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

plot_feature_distributions(
    df_final,
    numerical_cols_lst,
    categorical_cols_lst,
    bins=20,
    max_cols_per_row=4,
    top_k_categories=20,
)

# %% [markdown]
# ## Remove features with only one value

# %%
constant_cols = df_final.columns[df_final.nunique(dropna=True) <= 1]
print("Removed columns:", list(constant_cols))
df_final = df_final.drop(columns=constant_cols)
# Out:
# Removed columns: []

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 465 entries, 0 to 898
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   temperature              465 non-null    float64
#  1   study_id                 465 non-null    int64
#  2   instance                 465 non-null    object
#  3   mw_phbv                  465 non-null    float64
#  4   additive1_type           465 non-null    object
#  5   additive1_percentage_wt  465 non-null    float64
#  6   additive2_type           465 non-null    object
#  7   additive2_percentage_wt  465 non-null    float64
#  8   hb_ratio_mol             465 non-null    float64
#  9   hv_ratio_mol             465 non-null    float64
#  10  loss_modulus             465 non-null    float64
#  11  log_loss_modulus         465 non-null    float64
#  12  log_mw                   465 non-null    float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 50.9+ KB

# %% [markdown]
# ## Save

# %%
df_final.to_csv('rheological_DTS_data_loss_LM.csv', index=False)

# %% [markdown]
# ## Profiling

# %%
import sweetviz as sv

exclude_cols = ['study_id', 'instance']
df_subset = df_final.drop(columns=exclude_cols)

report = sv.analyze(df_subset)
report.show_html("dataset_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report dataset_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
